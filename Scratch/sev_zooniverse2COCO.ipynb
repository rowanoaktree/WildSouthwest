# %%
####
# Creator: Rowan Converse (rowanconverse@unm.edu)
# Date: 2022/08/02
# Purpose: Translate raw labels generated by volunteers on the participatory science platform Zooniverse into COCO format for public release 
# Ref COCO Camera Trap Standard: https://cocodataset.org/#format-data
####

#Load necessary modules
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
from collections import OrderedDict 

#Load data
path = r"/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/CleanLabelsForDistancePaper/sevilleta_clean.csv"
zooniverse = pd.read_csv(path)

# %%
###Annotations: import ID, Image ID, Category ID, bounding boxes (x,y, width, height). 
images = {}
annos = []
categories = {}

for i in range(len(zooniverse)):
  image_id = None
  imgrow = json.loads(zooniverse.subject_data[i])
  for key in imgrow.keys():
      name = imgrow[key]["Filename"]
      if name not in images:
        images[name] = len(images) + 1
      image_id = images[name]
      row = json.loads(zooniverse["annotations"][i])
      for j in range(len(row)):
        if row[j]['task'] == 'T1':
            annlist = row[j]['value']
            for k in range(len(annlist)):
                ann = annlist[k]
                x = ann["x"]
                y = ann["y"]
                w = ann["width"]
                h = ann["height"]
                bbox = [x, y, w, h]
        if row[j]['task'] == 'T0': 
          labelinfo = row[j]['value']
          for k in range(len(labelinfo)):
            lbl = labelinfo[k]
            label = lbl["choice"]
            if label not in categories:
   #label class has not yet been registered; add
                  categories[label] = len(categories) + 1
                  category_id = categories[label]
      annotation = {
        'annotation_id': len(annos)+1,
        'bbox': bbox,
        'category_id': category_id,
        'class': label,
        'image_id': image_id,
        'filename': name
      }
      annos.append(annotation)

# %%
annos
# Out:
# [{'annotation_id': 1,
#   'bbox': [1668.72705078125,
#    490.4450988769531,
#    109.727783203125,
#    217.81784057617188],
#   'category_id': 1,
#   'class': 'MULEDEER',
#   'image_id': 1,
#   'filename': 'Nuun1_0046.JPG'},
#  {'annotation_id': 2,
#   'bbox': [555.0716552734375,
#    496.9960021972656,
#    273.50067138671875,
#    265.3119812011719],
#   'category_id': 2,
#   'class': 'PRONGHORN',
#   'image_id': 2,
#   'filename': 'Nuun1_0120.JPG'},
#  {'annotation_id': 3,
#   'bbox': [1439.445068359375,
#    40.069759368896484,
#    222.7310791015625,
#    158.8596534729004],
#   'category_id': 4,
#   'class': 'VEHICLE',
#   'image_id': 3,
#   'filename': 'PinoCliff_0035.JPG'},
#  {'annotation_id': 4,
#   'bbox': [1411.6036376953125,
#    383.99273681640625,
#    124.4674072265625,
#    312.80615234375],
#   'category_id': 4,
#   'class': 'HUMAN',
#   'image_id': 4,
#   'filename': 'PinoFlat_0014.JPG'},
#  {'annotation_id': 5,
#   'bbox': [820.3836669921875,
#    356.1513366699219,
#    176.87469482421875,
#    388.1416320800781],
#   'category_id': 4,
#   'class': 'HUMAN',
#   'image_id': 5,
#   'filename': 'PinoFlat_0030.JPG'},
#  {'annotation_id': 6,
#   'bbox': [1048.0279541015625,
#    44.98294448852539,
#    219.45556640625,
#    153.94646835327148],
#   'category_id': 4,
#   'class': 'VEHICLE',
#   'image_id': 6,
#   'filename': 'PinoCliff_0040.JPG'},
#  {'annotation_id': 7,
#   'bbox': [1388.6754150390625,
#    405.283203125,
#    263.67431640625,
#    286.60247802734375],
#   'category_id': 5,
#   'class': 'AFRICANORYX',
#   'image_id': 7,
#   'filename': 'Nuun1_0204.JPG'},
#  {'annotation_id': 8,
#   'bbox': [1711.3079833984375,
#    333.22314453125,
#    211.2669677734375,
#    319.3570556640625],
#   'category_id': 5,
#   'class': 'AFRICANORYX',
#   'image_id': 8,
#   'filename': 'Nuun2_0040.JPG'},
#  {'annotation_id': 9,
#   'bbox': [1644.1611328125,
#    459.3282470703125,
#    278.413818359375,
#    242.3837890625],
#   'category_id': 5,
#   'class': 'MULEDEER',
#   'image_id': 9,
#   'filename': 'Nuun2_0511.JPG'},
#  {'annotation_id': 10,
#   'bbox': [903.9078369140625,
#    511.735595703125,
#    175.237060546875,
#    144.12005615234375],
#   'category_id': 5,
#   'class': 'PRONGHORN',
#   'image_id': 10,
#   'filename': 'Nuun1_0252.JPG'},
#  {'annotation_id': 11,
#   'bbox': [1.5194566249847412,
#    641.1160888671875,
#    226.0065290927887,
#    391.4171142578125],
#   'category_id': 5,
#   'class': 'PRONGHORN',
#   'image_id': 11,
#   'filename': 'Nuun1_0091.JPG'},
#  {'annotation_id': 12,
#   'bbox': [460.08343505859375,
#    510.09783935546875,
#    381.5906982421875,
#    466.75262451171875],
#   'category_id': 5,
#   'class': 'MULEDEER',
#   'image_id': 12,
#   'filename': 'PinoDrinker_0099.JPG'},
#  {'annotation_id': 13,
#   'bbox': [1788.28125,
#    411.8341064453125,
#    131.0181884765625,
#    214.54241943359375],
#   'category_id': 5,
#   'class': 'AFRICANORYX',
#   'image_id': 13,
#   'filename': 'Nuun2_1155.JPG'},
#  {'annotation_id': 14,
#   'bbox': [969.4169921875,
#    262.80084228515625,
#    211.2669677734375,
#    298.06658935546875],
#   'category_id': 6,
#   'class': 'ELK',
#   'image_id': 14,
#   'filename': 'PinoDrinker_0084.JPG'},
#  {'annotation_id': 15,
#   'bbox': [1657.262939453125,
#    460.9659729003906,
#    230.919677734375,
#    129.38052368164062],
#   'category_id': 6,
#   'class': 'VEHICLE',
#   'image_id': 15,
#   'filename': 'PinoFlat_0025.JPG'},
#  {'annotation_id': 16,
#   'bbox': [212.7864227294922,
#    795.0625610351562,
#    250.5724639892578,
#    193.251953125],
#   'category_id': 7,
#   'class': 'JAVELINA',
#   'image_id': 16,
#   'filename': 'PinoDrinker_0053.JPG'},
#  {'annotation_id': 17,
#   'bbox': [1126.638916015625,
#    54.8093147277832,
#    330.8211669921875,
#    139.2069206237793],
#   'category_id': 7,
#   'class': 'VEHICLE',
#   'image_id': 17,
#   'filename': 'PinoCliff_0006.JPG'},
#  {'annotation_id': 18,
#   'bbox': [1141.37841796875,
#    56.447044372558594,
#    320.994873046875,
#    139.20691680908203],
#   'category_id': 7,
#   'class': 'VEHICLE',
#   'image_id': 18,
#   'filename': 'PinoCliff_0011.JPG'},
#  {'annotation_id': 19,
#   'bbox': [532.1434936523438,
#    420.02276611328125,
#    157.221923828125,
#    255.48565673828125],
#   'category_id': 7,
#   'class': 'HUMAN',
#   'image_id': 19,
#   'filename': 'PinoFlat_0028.JPG'},
#  {'annotation_id': 20,
#   'bbox': [360.1819763183594,
#    320.121337890625,
#    298.0666198730469,
#    723.8759765625],
#   'category_id': 7,
#   'class': 'HUMAN',
#   'image_id': 20,
#   'filename': 'PinoDrinker_0108.JPG'},
#  {'annotation_id': 21,
#   'bbox': [1811.2093505859375,
#    483.8941650390625,
#    108.090087890625,
#    152.30877685546875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 21,
#   'filename': 'Nuun2_0151.JPG'},
#  {'annotation_id': 22,
#   'bbox': [1314.9776611328125,
#    392.1813659667969,
#    214.54248046875,
#    221.09335327148438],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 22,
#   'filename': 'Nuun2_1564.JPG'},
#  {'annotation_id': 23,
#   'bbox': [145.63955688476562,
#    135.05801391601562,
#    376.6775207519531,
#    879.4601745605469],
#   'category_id': 7,
#   'class': 'HUMAN',
#   'image_id': 23,
#   'filename': 'PinoFlat2_0063.JPG'},
#  {'annotation_id': 24,
#   'bbox': [1249.468505859375,
#    416.747314453125,
#    117.91650390625,
#    219.45562744140625],
#   'category_id': 7,
#   'class': 'HUMAN',
#   'image_id': 24,
#   'filename': 'PinoFlat2_0055.JPG'},
#  {'annotation_id': 25,
#   'bbox': [843.3118896484375,
#    382.3550109863281,
#    75.33551025390625,
#    217.81790161132812],
#   'category_id': 7,
#   'class': 'HUMAN',
#   'image_id': 25,
#   'filename': 'PinoDrinker_0031.JPG'},
#  {'annotation_id': 26,
#   'bbox': [399.4874572753906,
#    464.2414245605469,
#    299.7043151855469,
#    93.35055541992188],
#   'category_id': 7,
#   'class': 'VEHICLE',
#   'image_id': 26,
#   'filename': 'PinoFlat2_0037.JPG'},
#  {'annotation_id': 27,
#   'bbox': [212.7864227294922,
#    655.8556518554688,
#    574.8426666259766,
#    394.69256591796875],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 27,
#   'filename': 'Nuun1_0334.JPG'},
#  {'annotation_id': 28,
#   'bbox': [502.66436767578125,
#    817.9907836914062,
#    384.8662109375,
#    226.00653076171875],
#   'category_id': 8,
#   'class': 'COUGAR',
#   'image_id': 28,
#   'filename': 'PinoDrinker_0094.JPG'},
#  {'annotation_id': 29,
#   'bbox': [1180.6839599609375,
#    503.5469055175781,
#    232.557373046875,
#    288.2402038574219],
#   'category_id': 8,
#   'class': 'HUMAN',
#   'image_id': 29,
#   'filename': 'PinoFlat2_0033.JPG'},
#  {'annotation_id': 30,
#   'bbox': [1138.10302734375,
#    54.8093147277832,
#    317.71923828125,
#    132.65600204467773],
#   'category_id': 8,
#   'class': 'HUMAN',
#   'image_id': 30,
#   'filename': 'PinoCliff_0021.JPG'}]

# %%
for i in range(len(zooniverse)):
   row = json.loads(zooniverse["annotations"][i])
   if row[j]['task'] == 'T0': 
      labelinfo = row[j]['value']
      for k in range(len(labelinfo)):
            lbl = labelinfo[k]
            label = lbl["choice"]
            if label not in categories:
   #label class has not yet been registered; add
                  categories[label] = len(categories) + 1
                  category_id = categories[label]
      annotation = {
        'annotation_id': len(annos)+1,
        'category_id': category_id,
        'class': label,
      }
      annos.append(annotation)
annos
# Out:
# [{'annotation_id': 1, 'category_id': 1, 'class': 'MULEDEER'},
#  {'annotation_id': 2, 'category_id': 2, 'class': 'PRONGHORN'},
#  {'annotation_id': 3, 'category_id': 4, 'class': 'VEHICLE'},
#  {'annotation_id': 4, 'category_id': 4, 'class': 'HUMAN'},
#  {'annotation_id': 5, 'category_id': 4, 'class': 'HUMAN'},
#  {'annotation_id': 6, 'category_id': 4, 'class': 'VEHICLE'},
#  {'annotation_id': 7, 'category_id': 5, 'class': 'AFRICANORYX'},
#  {'annotation_id': 8, 'category_id': 5, 'class': 'AFRICANORYX'},
#  {'annotation_id': 9, 'category_id': 5, 'class': 'MULEDEER'},
#  {'annotation_id': 10, 'category_id': 5, 'class': 'PRONGHORN'},
#  {'annotation_id': 11, 'category_id': 5, 'class': 'PRONGHORN'},
#  {'annotation_id': 12, 'category_id': 5, 'class': 'MULEDEER'},
#  {'annotation_id': 13, 'category_id': 5, 'class': 'AFRICANORYX'},
#  {'annotation_id': 14, 'category_id': 6, 'class': 'ELK'},
#  {'annotation_id': 15, 'category_id': 6, 'class': 'VEHICLE'},
#  {'annotation_id': 16, 'category_id': 7, 'class': 'JAVELINA'},
#  {'annotation_id': 17, 'category_id': 7, 'class': 'VEHICLE'},
#  {'annotation_id': 18, 'category_id': 7, 'class': 'VEHICLE'},
#  {'annotation_id': 19, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 20, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 21, 'category_id': 7, 'class': 'PRONGHORN'},
#  {'annotation_id': 22, 'category_id': 7, 'class': 'AFRICANORYX'},
#  {'annotation_id': 23, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 24, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 25, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 26, 'category_id': 7, 'class': 'VEHICLE'},
#  {'annotation_id': 27, 'category_id': 7, 'class': 'MULEDEER'},
#  {'annotation_id': 28, 'category_id': 8, 'class': 'COUGAR'},
#  {'annotation_id': 29, 'category_id': 8, 'class': 'HUMAN'},
#  {'annotation_id': 30, 'category_id': 8, 'class': 'HUMAN'}]

# %%
with open("sevclean.json", "w") as outfile:
    json.dump(annos, outfile)
