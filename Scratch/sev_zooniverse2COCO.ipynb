# %%
####
# Creator: Rowan Converse (rowanconverse@unm.edu)
# Date: 2022/08/02
# Purpose: Translate raw labels generated by volunteers on the participatory science platform Zooniverse into COCO format for public release 
# Ref COCO Camera Trap Standard: https://cocodataset.org/#format-data
####

#Load necessary modules
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
from collections import OrderedDict 

#Load data
path = r"/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Labels/Scratch/rowanraw_20221130.csv"
zooniverse = pd.read_csv(path)

# %%
my20 = json.loads(zooniverse.annotations[13])
my20[1]["value"][1]
# Out:
# {'x': 0.59912109375,
#  'y': 453.5413818359375,
#  'tool': 0,
#  'frame': 0,
#  'width': 254.98313903808594,
#  'height': 248.5550537109375,
#  'details': [],
#  'tool_label': 'Animal'}

# %%
bboxes = []
#testanno = []
for i in range(len(zooniverse)):
  row = json.loads(zooniverse.annotations[i])
  if row[i]['task'] == 'T1':
    boxlist = row[j]['value']
    for k in range(len(boxlist)):
        box = boxlist[k]
        x = box["x"]
        y = box["y"]
        w = box["width"]
        h = box["height"]
        bbox = [x, y, w, h]
        bbox.append(bboxes)
  #annotation = {
  #      'annotation_id': len(bboxes)+1,
  #      'bbox': bbox
  #    }
  #testanno.append(annotation)

len(bboxes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> for i in range(len(zooniverse)):
#       <a href='vscode-notebook-cell:/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>   row = json.loads(zooniverse.annotations[i])
# ----> <a href='vscode-notebook-cell:/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>   if row[i]['task'] == 'T1':
#       <a href='vscode-notebook-cell:/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     boxlist = row[j]['value']
#       <a href='vscode-notebook-cell:/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     for k in range(len(boxlist)):
#
# IndexError: list index out of range

# %%
###Annotations: import ID, Image ID, Category ID, bounding boxes (x,y, width, height). 
images = {}
annos = []
categories = {}

for i in range(len(zooniverse)):
  image_id = None
  subject = zooniverse.subject_ids[i]
  imgrow = json.loads(zooniverse.subject_data[i])
  for key in imgrow.keys():
      name = imgrow[key]["Filename"]
      if name not in images:
        images[name] = len(images) + 1
      image_id = images[name]
      row = json.loads(zooniverse["annotations"][i])
      for j in range(len(row)):
        if row[j]['task'] == 'T1':
            annlist = row[j]['value']
            for k in range(len(annlist)):
                ann = annlist[k]
                x = ann["x"]
                y = ann["y"]
                w = ann["width"]
                h = ann["height"]
                bbox = [x, y, w, h]
        if row[j]['task'] == 'T0': 
          labelinfo = row[j]['value']
          for k in range(len(labelinfo)):
            lbl = labelinfo[k]
            label = lbl["choice"]
            if label not in categories:
   #label class has not yet been registered; add
                  categories[label] = len(categories) + 1
                  category_id = categories[label]
      annotation = {
        'annotation_id': len(annos)+1,
        'bbox': bbox,
        'category_id': category_id,
        'class': label,
        'image_id': image_id,
        'filename': name,
        'subjectID': subject
      }
      annos.append(annotation)

# %%
annos
# Out:
# [{'annotation_id': 1,
#   'bbox': [1461.9310302734375,
#    498.5384521484375,
#    216.414306640625,
#    186.416259765625],
#   'category_id': 1,
#   'class': 'MULEDEER',
#   'image_id': 1,
#   'filename': 'IMG_0058.JPG',
#   'subjectID': 83030587},
#  {'annotation_id': 2,
#   'bbox': [1142.66650390625,
#    470.68316650390625,
#    304.2655029296875,
#    304.26556396484375],
#   'category_id': 2,
#   'class': 'PRONGHORN',
#   'image_id': 2,
#   'filename': 'IMG_1502.JPG',
#   'subjectID': 83032065},
#  {'annotation_id': 3,
#   'bbox': [2.7418365478515625,
#    644.2431030273438,
#    201.41525268554688,
#    329.97821044921875],
#   'category_id': 2,
#   'class': 'PRONGHORN',
#   'image_id': 3,
#   'filename': 'nuun1_0421.JPG',
#   'subjectID': 83030430},
#  {'annotation_id': 4,
#   'bbox': [69.166015625, 522.1082763671875, 68.56689453125, 55.71063232421875],
#   'category_id': 3,
#   'class': 'COYOTE',
#   'image_id': 4,
#   'filename': 'IMG_0819.JPG',
#   'subjectID': 83031348},
#  {'annotation_id': 5,
#   'bbox': [1022.6743774414062,
#    669.9556884765625,
#    246.41229248046875,
#    156.418212890625],
#   'category_id': 4,
#   'class': 'JAVELINA',
#   'image_id': 5,
#   'filename': 'IMG_0054.JPG',
#   'subjectID': 83032129},
#  {'annotation_id': 6,
#   'bbox': [1022.6743774414062,
#    669.9556884765625,
#    246.41229248046875,
#    156.418212890625],
#   'category_id': 5,
#   'class': 'NOTHINGHERE',
#   'image_id': 6,
#   'filename': 'IMG_0515.JPG',
#   'subjectID': 83031044},
#  {'annotation_id': 7,
#   'bbox': [793.40380859375,
#    359.2619934082031,
#    188.5589599609375,
#    383.5460510253906],
#   'category_id': 6,
#   'class': 'HUMAN',
#   'image_id': 7,
#   'filename': 'IMG_0029.JPG',
#   'subjectID': 83032126},
#  {'annotation_id': 8,
#   'bbox': [1065.5286865234375,
#    539.2500610351562,
#    237.8414306640625,
#    452.11297607421875],
#   'category_id': 6,
#   'class': 'HUMAN',
#   'image_id': 8,
#   'filename': 'IMG_0012.JPG',
#   'subjectID': 83032130},
#  {'annotation_id': 9,
#   'bbox': [1065.5286865234375,
#    539.2500610351562,
#    237.8414306640625,
#    452.11297607421875],
#   'category_id': 6,
#   'class': 'NOTHINGHERE',
#   'image_id': 9,
#   'filename': 'nuun1_0294.JPG',
#   'subjectID': 83030295},
#  {'annotation_id': 10,
#   'bbox': [819.116455078125,
#    429.9715576171875,
#    205.70068359375,
#    158.56097412109375],
#   'category_id': 6,
#   'class': 'MULEDEER',
#   'image_id': 10,
#   'filename': 'IMG_0263.JPG',
#   'subjectID': 83030792},
#  {'annotation_id': 11,
#   'bbox': [819.116455078125,
#    429.9715576171875,
#    205.70068359375,
#    158.56097412109375],
#   'category_id': 6,
#   'class': 'NOTHINGHERE',
#   'image_id': 11,
#   'filename': 'nuun1_0344.JPG',
#   'subjectID': 83030351},
#  {'annotation_id': 12,
#   'bbox': [579.13232421875,
#    479.2540283203125,
#    42.854248046875,
#    38.56884765625],
#   'category_id': 6,
#   'class': 'PRONGHORN',
#   'image_id': 12,
#   'filename': 'IMG_0795.JPG',
#   'subjectID': 83031324},
#  {'annotation_id': 13,
#   'bbox': [1275.5147705078125,
#    507.10931396484375,
#    158.56103515625,
#    85.7086181640625],
#   'category_id': 6,
#   'class': 'COYOTE',
#   'image_id': 13,
#   'filename': 'IMG_0328.JPG',
#   'subjectID': 83030857},
#  {'annotation_id': 14,
#   'bbox': [0.59912109375,
#    453.5413818359375,
#    254.98313903808594,
#    248.5550537109375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 14,
#   'filename': 'IMG_1354.JPG',
#   'subjectID': 83031917},
#  {'annotation_id': 15,
#   'bbox': [0.59912109375,
#    453.5413818359375,
#    254.98313903808594,
#    248.5550537109375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 15,
#   'filename': 'nuun1_0159.JPG',
#   'subjectID': 83030148},
#  {'annotation_id': 16,
#   'bbox': [885.5405883789062,
#    414.9725341796875,
#    407.11590576171875,
#    344.97711181640625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 16,
#   'filename': 'nuun1_0177.JPG',
#   'subjectID': 83030166},
#  {'annotation_id': 17,
#   'bbox': [885.5405883789062,
#    414.9725341796875,
#    407.11590576171875,
#    344.97711181640625],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 17,
#   'filename': 'IMG_1023.JPG',
#   'subjectID': 83031561},
#  {'annotation_id': 18,
#   'bbox': [1483.358154296875,
#    423.54339599609375,
#    304.265625,
#    222.8424072265625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 18,
#   'filename': 'nuun1_0442.JPG',
#   'subjectID': 83030451},
#  {'annotation_id': 19,
#   'bbox': [1607.6357421875,
#    380.6890869140625,
#    308.551025390625,
#    269.982177734375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 19,
#   'filename': 'IMG_1105.JPG',
#   'subjectID': 83031668},
#  {'annotation_id': 20,
#   'bbox': [1607.6357421875,
#    380.6890869140625,
#    308.551025390625,
#    269.982177734375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 20,
#   'filename': 'IMG_0518.JPG',
#   'subjectID': 83031047},
#  {'annotation_id': 21,
#   'bbox': [1607.6357421875,
#    380.6890869140625,
#    308.551025390625,
#    269.982177734375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 21,
#   'filename': 'IMG_0863.JPG',
#   'subjectID': 83031392},
#  {'annotation_id': 22,
#   'bbox': [1397.649658203125,
#    404.25897216796875,
#    145.70458984375,
#    167.1318359375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 22,
#   'filename': 'IMG_1161.JPG',
#   'subjectID': 83031724},
#  {'annotation_id': 23,
#   'bbox': [1397.649658203125,
#    404.25897216796875,
#    145.70458984375,
#    167.1318359375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 23,
#   'filename': 'IMG_0056.JPG',
#   'subjectID': 83030585},
#  {'annotation_id': 24,
#   'bbox': [750.549560546875,
#    314.2649230957031,
#    392.116943359375,
#    471.3974304199219],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 24,
#   'filename': 'IMG_0645.JPG',
#   'subjectID': 83031174},
#  {'annotation_id': 25,
#   'bbox': [1468.3592529296875,
#    354.9765319824219,
#    334.2635498046875,
#    334.2635803222656],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 25,
#   'filename': 'IMG_0937.JPG',
#   'subjectID': 83031472},
#  {'annotation_id': 26,
#   'bbox': [1815.4791259765625,
#    498.5384521484375,
#    102.850341796875,
#    220.69970703125],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 26,
#   'filename': 'nuun1_0263.JPG',
#   'subjectID': 83030262},
#  {'annotation_id': 27,
#   'bbox': [1236.9459228515625,
#    429.9715576171875,
#    137.1337890625,
#    207.8433837890625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 27,
#   'filename': 'IMG_0771.JPG',
#   'subjectID': 83031300},
#  {'annotation_id': 28,
#   'bbox': [504.13726806640625,
#    392.4739990234375,
#    254.98309326171875,
#    232.48468017578125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 28,
#   'filename': 'IMG_0316.JPG',
#   'subjectID': 83030845},
#  {'annotation_id': 29,
#   'bbox': [-12.257171630859375,
#    558.5344848632812,
#    66.42417907714844,
#    98.56494140625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 29,
#   'filename': 'nuun1_0523.JPG',
#   'subjectID': 83030532},
#  {'annotation_id': 30,
#   'bbox': [1817.621826171875,
#    407.47308349609375,
#    104.9930419921875,
#    226.05645751953125],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 30,
#   'filename': 'IMG_1430.JPG',
#   'subjectID': 83031993},
#  {'annotation_id': 31,
#   'bbox': [823.40185546875,
#    494.25299072265625,
#    321.4073486328125,
#    272.1248779296875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 31,
#   'filename': 'nuun1_0521.JPG',
#   'subjectID': 83030530},
#  {'annotation_id': 32,
#   'bbox': [823.40185546875,
#    494.25299072265625,
#    321.4073486328125,
#    272.1248779296875],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 32,
#   'filename': 'IMG_1461.JPG',
#   'subjectID': 83032024},
#  {'annotation_id': 33,
#   'bbox': [1766.1966552734375,
#    483.5394592285156,
#    152.1328125,
#    297.8374328613281],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 33,
#   'filename': 'IMG_0334.JPG',
#   'subjectID': 83030863},
#  {'annotation_id': 34,
#   'bbox': [1689.0589599609375,
#    352.83380126953125,
#    227.1278076171875,
#    304.26556396484375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 34,
#   'filename': 'IMG_0824.JPG',
#   'subjectID': 83031353},
#  {'annotation_id': 35,
#   'bbox': [255.58226013183594,
#    294.9804992675781,
#    452.11293029785156,
#    505.6808166503906],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 35,
#   'filename': 'IMG_1539.JPG',
#   'subjectID': 83032102},
#  {'annotation_id': 36,
#   'bbox': [255.58226013183594,
#    294.9804992675781,
#    452.11293029785156,
#    505.6808166503906],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 36,
#   'filename': 'IMG_0162.JPG',
#   'subjectID': 83030691},
#  {'annotation_id': 37,
#   'bbox': [1659.0609130859375,
#    426.75750732421875,
#    259.2685546875,
#    245.34088134765625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 37,
#   'filename': 'IMG_0499.JPG',
#   'subjectID': 83031028},
#  {'annotation_id': 38,
#   'bbox': [1524.06982421875,
#    492.1103210449219,
#    274.2677001953125,
#    340.6917419433594],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 38,
#   'filename': 'IMG_0089.JPG',
#   'subjectID': 83030618},
#  {'annotation_id': 39,
#   'bbox': [420.5713195800781,
#    485.6821594238281,
#    224.98513793945312,
#    156.41824340820312],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 39,
#   'filename': 'IMG_1185.JPG',
#   'subjectID': 83031748},
#  {'annotation_id': 40,
#   'bbox': [1292.656494140625,
#    367.8328857421875,
#    173.56005859375,
#    212.1287841796875],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 40,
#   'filename': 'IMG_0305.JPG',
#   'subjectID': 83030834},
#  {'annotation_id': 41,
#   'bbox': [1736.1986083984375,
#    417.1152648925781,
#    188.5589599609375,
#    199.27255249023438],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 41,
#   'filename': 'IMG_0917.JPG',
#   'subjectID': 83031451},
#  {'annotation_id': 42,
#   'bbox': [54.16700744628906,
#    492.1103210449219,
#    72.85232543945312,
#    40.711578369140625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 42,
#   'filename': 'IMG_1289.JPG',
#   'subjectID': 83031852},
#  {'annotation_id': 43,
#   'bbox': [1663.3463134765625,
#    462.1122741699219,
#    252.8404541015625,
#    190.70169067382812],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 43,
#   'filename': 'IMG_0078.JPG',
#   'subjectID': 83030607},
#  {'annotation_id': 44,
#   'bbox': [1849.7625732421875,
#    492.1103210449219,
#    79.2803955078125,
#    199.27255249023438],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 44,
#   'filename': 'IMG_0368.JPG',
#   'subjectID': 83030897},
#  {'annotation_id': 45,
#   'bbox': [1731.9132080078125,
#    404.25897216796875,
#    186.416259765625,
#    366.40435791015625],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 45,
#   'filename': 'IMG_1390.JPG',
#   'subjectID': 83031953},
#  {'annotation_id': 46,
#   'bbox': [-3.686309814453125,
#    429.9715576171875,
#    98.56491088867188,
#    193.915771484375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 46,
#   'filename': 'IMG_1528.JPG',
#   'subjectID': 83032091},
#  {'annotation_id': 47,
#   'bbox': [1826.192626953125,
#    417.1152648925781,
#    102.850341796875,
#    147.84738159179688],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 47,
#   'filename': 'IMG_0669.JPG',
#   'subjectID': 83031198},
#  {'annotation_id': 48,
#   'bbox': [1618.3492431640625,
#    341.04888916015625,
#    304.265625,
#    369.618408203125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 48,
#   'filename': 'IMG_1312.JPG',
#   'subjectID': 83031875},
#  {'annotation_id': 49,
#   'bbox': [1680.488037109375,
#    315.3363037109375,
#    252.8404541015625,
#    356.7620849609375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 49,
#   'filename': 'IMG_0676.JPG',
#   'subjectID': 83031205},
#  {'annotation_id': 50,
#   'bbox': [870.5416259765625,
#    603.531494140625,
#    368.5469970703125,
#    329.97821044921875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 50,
#   'filename': 'nuun1_0158.JPG',
#   'subjectID': 83030147},
#  {'annotation_id': 51,
#   'bbox': [1376.222412109375,
#    452.47003173828125,
#    119.9920654296875,
#    155.346923828125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 51,
#   'filename': 'nuun1_0390.JPG',
#   'subjectID': 83030399},
#  {'annotation_id': 52,
#   'bbox': [1376.222412109375,
#    452.47003173828125,
#    119.9920654296875,
#    155.346923828125],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 52,
#   'filename': 'IMG_0131.JPG',
#   'subjectID': 83030660},
#  {'annotation_id': 53,
#   'bbox': [906.9677734375,
#    511.3946533203125,
#    171.417236328125,
#    143.56201171875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 53,
#   'filename': 'nuun1_0252.JPG',
#   'subjectID': 83030251},
#  {'annotation_id': 54,
#   'bbox': [1759.7685546875,
#    351.762451171875,
#    162.8463134765625,
#    234.6273193359375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 54,
#   'filename': 'IMG_0893.JPG',
#   'subjectID': 83031422},
#  {'annotation_id': 55,
#   'bbox': [-1.5435943603515625,
#    421.40069580078125,
#    239.984130859375,
#    261.41131591796875],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 55,
#   'filename': 'IMG_0232.JPG',
#   'subjectID': 83030761},
#  {'annotation_id': 56,
#   'bbox': [-1.5435943603515625,
#    421.40069580078125,
#    239.984130859375,
#    261.41131591796875],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 56,
#   'filename': 'nuun1_0401.JPG',
#   'subjectID': 83030410},
#  {'annotation_id': 57,
#   'bbox': [354.14715576171875,
#    453.54144287109375,
#    152.1328125,
#    107.1357421875],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 57,
#   'filename': 'IMG_0244.JPG',
#   'subjectID': 83030773},
#  {'annotation_id': 58,
#   'bbox': [1534.7833251953125,
#    485.6821594238281,
#    289.2666015625,
#    329.9781799316406],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 58,
#   'filename': 'nuun1_0067.JPG',
#   'subjectID': 83030047},
#  {'annotation_id': 59,
#   'bbox': [930.53759765625,
#    354.97650146484375,
#    503.5382080078125,
#    411.4013671875],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 59,
#   'filename': 'nuun1_0059.JPG',
#   'subjectID': 83030037},
#  {'annotation_id': 60,
#   'bbox': [49.88157653808594,
#    507.10931396484375,
#    306.40830993652344,
#    190.70166015625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 60,
#   'filename': 'nuun1_0384.JPG',
#   'subjectID': 83030393},
#  {'annotation_id': 61,
#   'bbox': [1408.3631591796875,
#    333.54937744140625,
#    272.1248779296875,
#    299.980224609375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 61,
#   'filename': 'IMG_1277.JPG',
#   'subjectID': 83031840},
#  {'annotation_id': 62,
#   'bbox': [1408.3631591796875,
#    333.54937744140625,
#    272.1248779296875,
#    299.980224609375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 62,
#   'filename': 'nuun1_0147.JPG',
#   'subjectID': 83030133},
#  {'annotation_id': 63,
#   'bbox': [1243.3740234375,
#    511.394775390625,
#    239.9842529296875,
#    171.41729736328125],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 63,
#   'filename': 'nuun1_0257.JPG',
#   'subjectID': 83030256},
#  {'annotation_id': 64,
#   'bbox': [339.1481628417969,
#    496.395751953125,
#    132.84835815429688,
#    119.9920654296875],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 64,
#   'filename': 'IMG_0246.JPG',
#   'subjectID': 83030775},
#  {'annotation_id': 65,
#   'bbox': [397.00146484375,
#    477.1112976074219,
#    117.849365234375,
#    126.42019653320312],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 65,
#   'filename': 'IMG_0143.JPG',
#   'subjectID': 83030672},
#  {'annotation_id': 66,
#   'bbox': [-1.5435943603515625,
#    485.68218994140625,
#    186.41624450683594,
#    306.4083251953125],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 66,
#   'filename': 'nuun1_0509.JPG',
#   'subjectID': 83030518},
#  {'annotation_id': 67,
#   'bbox': [-1.5435943603515625,
#    485.68218994140625,
#    186.41624450683594,
#    306.4083251953125],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 67,
#   'filename': 'IMG_0315.JPG',
#   'subjectID': 83030844},
#  {'annotation_id': 68,
#   'bbox': [-1.5435943603515625,
#    492.1103210449219,
#    74.99504089355469,
#    129.63436889648438],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 68,
#   'filename': 'nuun1_0199.JPG',
#   'subjectID': 83030191},
#  {'annotation_id': 69,
#   'bbox': [-1.5435943603515625,
#    492.1103210449219,
#    74.99504089355469,
#    129.63436889648438],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 69,
#   'filename': 'IMG_1397.JPG',
#   'subjectID': 83031960},
#  {'annotation_id': 70,
#   'bbox': [557.7051391601562,
#    514.6088256835938,
#    186.416259765625,
#    196.05841064453125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 70,
#   'filename': 'nuun1_0408.JPG',
#   'subjectID': 83030417},
#  {'annotation_id': 71,
#   'bbox': [647.69921875, 474.9686279296875, 34.283447265625, 36.4261474609375],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 71,
#   'filename': 'IMG_0798.JPG',
#   'subjectID': 83031327},
#  {'annotation_id': 72,
#   'bbox': [1680.488037109375,
#    416.0439147949219,
#    235.69873046875,
#    226.05648803710938],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 72,
#   'filename': 'IMG_1158.JPG',
#   'subjectID': 83031721},
#  {'annotation_id': 73,
#   'bbox': [2.7418365478515625,
#    590.6752319335938,
#    422.1149444580078,
#    447.82757568359375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 73,
#   'filename': 'nuun1_0322.JPG',
#   'subjectID': 83030327},
#  {'annotation_id': 74,
#   'bbox': [2.7418365478515625,
#    477.111328125,
#    254.98313903808594,
#    248.55499267578125],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 74,
#   'filename': 'IMG_0076.JPG',
#   'subjectID': 83030605},
#  {'annotation_id': 75,
#   'bbox': [2.7418365478515625,
#    477.111328125,
#    254.98313903808594,
#    248.55499267578125],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 75,
#   'filename': 'IMG_0966.JPG',
#   'subjectID': 83031501},
#  {'annotation_id': 76,
#   'bbox': [2.7418365478515625,
#    590.6752319335938,
#    70.70960998535156,
#    228.19915771484375],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 76,
#   'filename': 'nuun1_0124.JPG',
#   'subjectID': 83030108},
#  {'annotation_id': 77,
#   'bbox': [1446.93212890625,
#    541.3927612304688,
#    233.555908203125,
#    115.7066650390625],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 77,
#   'filename': 'IMG_0361.JPG',
#   'subjectID': 83030890},
#  {'annotation_id': 78,
#   'bbox': [1446.93212890625,
#    541.3927612304688,
#    233.555908203125,
#    115.7066650390625],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 78,
#   'filename': 'IMG_0174.JPG',
#   'subjectID': 83030703},
#  {'annotation_id': 79,
#   'bbox': [979.820068359375,
#    500.6811828613281,
#    83.56591796875,
#    164.98910522460938],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 79,
#   'filename': 'nuun1_0254.JPG',
#   'subjectID': 83030253},
#  {'annotation_id': 80,
#   'bbox': [979.820068359375,
#    500.6811828613281,
#    83.56591796875,
#    164.98910522460938],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 80,
#   'filename': 'IMG_1361.JPG',
#   'subjectID': 83031924},
#  {'annotation_id': 81,
#   'bbox': [979.820068359375,
#    500.6811828613281,
#    83.56591796875,
#    164.98910522460938],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 81,
#   'filename': 'IMG_0167.JPG',
#   'subjectID': 83030696},
#  {'annotation_id': 82,
#   'bbox': [979.820068359375,
#    500.6811828613281,
#    83.56591796875,
#    164.98910522460938],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 82,
#   'filename': 'IMG_1347.JPG',
#   'subjectID': 83031910},
#  {'annotation_id': 83,
#   'bbox': [979.820068359375,
#    500.6811828613281,
#    83.56591796875,
#    164.98910522460938],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 83,
#   'filename': 'IMG_0120.JPG',
#   'subjectID': 83030649},
#  {'annotation_id': 84,
#   'bbox': [292.0084228515625,
#    356.0478820800781,
#    357.83349609375,
#    388.9028625488281],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 84,
#   'filename': 'IMG_1270.JPG',
#   'subjectID': 83031833},
#  {'annotation_id': 85,
#   'bbox': [431.284912109375,
#    511.394775390625,
#    244.26959228515625,
#    308.551025390625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 85,
#   'filename': 'nuun1_0492.JPG',
#   'subjectID': 83030501},
#  {'annotation_id': 86,
#   'bbox': [1650.489990234375,
#    463.18365478515625,
#    274.267578125,
#    199.27252197265625],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 86,
#   'filename': 'IMG_1004.JPG',
#   'subjectID': 83031539},
#  {'annotation_id': 87,
#   'bbox': [1650.489990234375,
#    463.18365478515625,
#    274.267578125,
#    199.27252197265625],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 87,
#   'filename': 'IMG_1508.JPG',
#   'subjectID': 83032071},
#  {'annotation_id': 88,
#   'bbox': [1894.759521484375,
#    434.2569885253906,
#    23.5699462890625,
#    154.27554321289062],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 88,
#   'filename': 'IMG_0621.JPG',
#   'subjectID': 83031150},
#  {'annotation_id': 89,
#   'bbox': [1474.787353515625,
#    423.5434265136719,
#    293.552001953125,
#    200.34390258789062],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 89,
#   'filename': 'IMG_0154.JPG',
#   'subjectID': 83030683},
#  {'annotation_id': 90,
#   'bbox': [1391.221435546875,
#    432.1142883300781,
#    119.9920654296875,
#    141.41921997070312],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 90,
#   'filename': 'IMG_1167.JPG',
#   'subjectID': 83031730},
#  {'annotation_id': 91,
#   'bbox': [1391.221435546875,
#    432.1142883300781,
#    119.9920654296875,
#    141.41921997070312],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 91,
#   'filename': 'nuun1_0370.JPG',
#   'subjectID': 83030379},
#  {'annotation_id': 92,
#   'bbox': [1851.9052734375,
#    410.6871337890625,
#    68.56689453125,
#    126.42022705078125],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 92,
#   'filename': 'IMG_0786.JPG',
#   'subjectID': 83031315},
#  {'annotation_id': 93,
#   'bbox': [-12.257171630859375,
#    466.3977355957031,
#    72.85232543945312,
#    86.77999877929688],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 93,
#   'filename': 'IMG_0439.JPG',
#   'subjectID': 83030968},
#  {'annotation_id': 94,
#   'bbox': [-12.257171630859375,
#    466.3977355957031,
#    72.85232543945312,
#    86.77999877929688],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 94,
#   'filename': 'IMG_1301.JPG',
#   'subjectID': 83031864},
#  {'annotation_id': 95,
#   'bbox': [324.149169921875,
#    500.6811828613281,
#    201.41522216796875,
#    167.13180541992188],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 95,
#   'filename': 'IMG_1145.JPG',
#   'subjectID': 83031708},
#  {'annotation_id': 96,
#   'bbox': [324.149169921875,
#    500.6811828613281,
#    201.41522216796875,
#    167.13180541992188],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 96,
#   'filename': 'IMG_1541.JPG',
#   'subjectID': 83032104},
#  {'annotation_id': 97,
#   'bbox': [324.149169921875,
#    500.6811828613281,
#    201.41522216796875,
#    167.13180541992188],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 97,
#   'filename': 'IMG_1070.JPG',
#   'subjectID': 83031625},
#  {'annotation_id': 98,
#   'bbox': [1723.34228515625,
#    432.1142883300781,
#    79.280517578125,
#    214.27157592773438],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 98,
#   'filename': 'IMG_0281.JPG',
#   'subjectID': 83030810},
#  {'annotation_id': 99,
#   'bbox': [-3.686309814453125,
#    468.5404052734375,
#    377.117919921875,
#    415.68682861328125],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 99,
#   'filename': 'IMG_0241.JPG',
#   'subjectID': 83030770},
#  {'annotation_id': 100,
#   'bbox': [444.1412353515625,
#    468.5404052734375,
#    199.27252197265625,
#    132.848388671875],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 100,
#   'filename': 'IMG_0392.JPG',
#   'subjectID': 83030921},
#  {'annotation_id': 101,
#   'bbox': [1446.9320068359375,
#    470.68316650390625,
#    377.117919921875,
#    233.55596923828125],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 101,
#   'filename': 'IMG_0268.JPG',
#   'subjectID': 83030797},
#  {'annotation_id': 102,
#   'bbox': [1684.7734375,
#    413.9012145996094,
#    171.417236328125,
#    217.48562622070312],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 102,
#   'filename': 'IMG_0068.JPG',
#   'subjectID': 83030597},
#  {'annotation_id': 103,
#   'bbox': [1183.3780517578125,
#    394.61676025390625,
#    293.552001953125,
#    217.485595703125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 103,
#   'filename': 'IMG_0838.JPG',
#   'subjectID': 83031367},
#  {'annotation_id': 104,
#   'bbox': [1706.20068359375,
#    474.9685974121094,
#    222.84228515625,
#    248.55496215820312],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 104,
#   'filename': 'nuun1_0433.JPG',
#   'subjectID': 83030442},
#  {'annotation_id': 105,
#   'bbox': [1438.3612060546875,
#    465.32635498046875,
#    128.5628662109375,
#    178.916748046875],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 105,
#   'filename': 'IMG_0704.JPG',
#   'subjectID': 83031233},
#  {'annotation_id': 106,
#   'bbox': [1438.3612060546875,
#    465.32635498046875,
#    128.5628662109375,
#    178.916748046875],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 106,
#   'filename': 'nuun1_0513.JPG',
#   'subjectID': 83030522},
#  {'annotation_id': 107,
#   'bbox': [1566.9241943359375,
#    326.04986572265625,
#    342.8343505859375,
#    393.18829345703125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 107,
#   'filename': 'IMG_1309.JPG',
#   'subjectID': 83031872},
#  {'annotation_id': 108,
#   'bbox': [1860.47607421875,
#    432.1142883300781,
#    66.4241943359375,
#    234.62734985351562],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 108,
#   'filename': 'IMG_0539.JPG',
#   'subjectID': 83031068},
#  {'annotation_id': 109,
#   'bbox': [1860.47607421875,
#    432.1142883300781,
#    66.4241943359375,
#    234.62734985351562],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 109,
#   'filename': 'nuun1_0435.JPG',
#   'subjectID': 83030444},
#  {'annotation_id': 110,
#   'bbox': [1644.0618896484375,
#    347.47705078125,
#    276.4102783203125,
#    350.333984375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 110,
#   'filename': 'IMG_0942.JPG',
#   'subjectID': 83031477},
#  {'annotation_id': 111,
#   'bbox': [285.58026123046875,
#    474.96856689453125,
#    77.13775634765625,
#    85.7086181640625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 111,
#   'filename': 'IMG_0732.JPG',
#   'subjectID': 83031261},
#  {'annotation_id': 112,
#   'bbox': [-7.97174072265625,
#    515.68017578125,
#    518.5371398925781,
#    529.250732421875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 112,
#   'filename': 'IMG_1235.JPG',
#   'subjectID': 83031798},
#  {'annotation_id': 113,
#   'bbox': [1545.4969482421875,
#    279.9814758300781,
#    374.9752197265625,
#    440.3280334472656],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 113,
#   'filename': 'IMG_0573.JPG',
#   'subjectID': 83031102},
#  {'annotation_id': 114,
#   'bbox': [1074.099609375,
#    421.40069580078125,
#    291.4093017578125,
#    239.984130859375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 114,
#   'filename': 'nuun1_0230.JPG',
#   'subjectID': 83030224},
#  {'annotation_id': 115,
#   'bbox': [1074.099609375,
#    421.40069580078125,
#    291.4093017578125,
#    239.984130859375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 115,
#   'filename': 'IMG_0638.JPG',
#   'subjectID': 83031167},
#  {'annotation_id': 116,
#   'bbox': [1881.9033203125,
#    539.2500610351562,
#    40.7115478515625,
#    182.13079833984375],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 116,
#   'filename': 'nuun1_0267.JPG',
#   'subjectID': 83030266},
#  {'annotation_id': 117,
#   'bbox': [1586.20849609375,
#    522.1083374023438,
#    113.5640869140625,
#    128.56292724609375],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 117,
#   'filename': 'nuun1_0268.JPG',
#   'subjectID': 83030267},
#  {'annotation_id': 118,
#   'bbox': [1354.7952880859375,
#    489.96759033203125,
#    132.848388671875,
#    252.84033203125],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 118,
#   'filename': 'IMG_0090.JPG',
#   'subjectID': 83030619},
#  {'annotation_id': 119,
#   'bbox': [1354.7952880859375,
#    489.96759033203125,
#    132.848388671875,
#    252.84033203125],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 119,
#   'filename': 'nuun1_0444.JPG',
#   'subjectID': 83030453},
#  {'annotation_id': 120,
#   'bbox': [1819.7645263671875,
#    410.6871337890625,
#    102.850341796875,
#    160.70367431640625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 120,
#   'filename': 'IMG_0589.JPG',
#   'subjectID': 83031118},
#  {'annotation_id': 121,
#   'bbox': [1524.06982421875,
#    320.6930847167969,
#    272.1248779296875,
#    387.8315124511719],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 121,
#   'filename': 'IMG_0672.JPG',
#   'subjectID': 83031201},
#  {'annotation_id': 122,
#   'bbox': [1631.20556640625,
#    412.829833984375,
#    199.2725830078125,
#    256.05450439453125],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 122,
#   'filename': 'IMG_0702.JPG',
#   'subjectID': 83031231},
#  {'annotation_id': 123,
#   'bbox': [1481.2154541015625,
#    770.6632690429688,
#    439.2567138671875,
#    276.41033935546875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 123,
#   'filename': 'nuun1_0283.JPG',
#   'subjectID': 83030284},
#  {'annotation_id': 124,
#   'bbox': [1481.2154541015625,
#    770.6632690429688,
#    439.2567138671875,
#    276.41033935546875],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 124,
#   'filename': 'IMG_0710.JPG',
#   'subjectID': 83031239},
#  {'annotation_id': 125,
#   'bbox': [930.53759765625,
#    504.96661376953125,
#    85.7086181640625,
#    169.2745361328125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 125,
#   'filename': 'IMG_1128.JPG',
#   'subjectID': 83031691},
#  {'annotation_id': 126,
#   'bbox': [1836.90625,
#    417.1152648925781,
#    89.9940185546875,
#    224.98513793945312],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 126,
#   'filename': 'IMG_0566.JPG',
#   'subjectID': 83031095},
#  {'annotation_id': 127,
#   'bbox': [1624.7774658203125,
#    432.1142883300781,
#    222.8424072265625,
#    265.6967468261719],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 127,
#   'filename': 'IMG_0093.JPG',
#   'subjectID': 83030622},
#  {'annotation_id': 128,
#   'bbox': [1511.2135009765625,
#    440.68511962890625,
#    175.70263671875,
#    216.41424560546875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 128,
#   'filename': 'IMG_0077.JPG',
#   'subjectID': 83030606},
#  {'annotation_id': 129,
#   'bbox': [1886.188720703125,
#    472.82586669921875,
#    44.9970703125,
#    193.915771484375],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 129,
#   'filename': 'IMG_0753.JPG',
#   'subjectID': 83031282},
#  {'annotation_id': 130,
#   'bbox': [1599.0648193359375,
#    453.54144287109375,
#    263.5540771484375,
#    216.41424560546875],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 130,
#   'filename': 'nuun1_0234.JPG',
#   'subjectID': 83030229},
#  {'annotation_id': 131,
#   'bbox': [1851.9052734375,
#    372.1182556152344,
#    72.852294921875,
#    132.84835815429688],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 131,
#   'filename': 'IMG_1262.JPG',
#   'subjectID': 83031825},
#  {'annotation_id': 132,
#   'bbox': [1459.788330078125,
#    534.9645385742188,
#    336.4063720703125,
#    370.68988037109375],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 132,
#   'filename': 'nuun1_0340.JPG',
#   'subjectID': 83030347},
#  {'annotation_id': 133,
#   'bbox': [1459.788330078125,
#    534.9645385742188,
#    336.4063720703125,
#    370.68988037109375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 133,
#   'filename': 'IMG_0699.JPG',
#   'subjectID': 83031228},
#  {'annotation_id': 134,
#   'bbox': [1459.788330078125,
#    534.9645385742188,
#    336.4063720703125,
#    370.68988037109375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 134,
#   'filename': 'IMG_0767.JPG',
#   'subjectID': 83031296},
#  {'annotation_id': 135,
#   'bbox': [1459.788330078125,
#    534.9645385742188,
#    336.4063720703125,
#    370.68988037109375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 135,
#   'filename': 'IMG_0555.JPG',
#   'subjectID': 83031084},
#  {'annotation_id': 136,
#   'bbox': [52.0242919921875,
#    466.3977355957031,
#    139.27650451660156,
#    113.56393432617188],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 136,
#   'filename': 'IMG_0340.JPG',
#   'subjectID': 83030869},
#  {'annotation_id': 137,
#   'bbox': [1594.7794189453125,
#    424.6147766113281,
#    327.83544921875,
#    324.6213684082031],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 137,
#   'filename': 'IMG_0877.JPG',
#   'subjectID': 83031406},
#  {'annotation_id': 138,
#   'bbox': [1594.7794189453125,
#    424.6147766113281,
#    327.83544921875,
#    324.6213684082031],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 138,
#   'filename': 'nuun1_0471.JPG',
#   'subjectID': 83030480},
#  {'annotation_id': 139,
#   'bbox': [1594.7794189453125,
#    424.6147766113281,
#    327.83544921875,
#    324.6213684082031],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 139,
#   'filename': 'IMG_0891.JPG',
#   'subjectID': 83031420},
#  {'annotation_id': 140,
#   'bbox': [1594.7794189453125,
#    424.6147766113281,
#    327.83544921875,
#    324.6213684082031],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 140,
#   'filename': 'IMG_1526.JPG',
#   'subjectID': 83032089},
#  {'annotation_id': 141,
#   'bbox': [1020.5316772460938,
#    498.5384216308594,
#    308.55108642578125,
#    244.26962280273438],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 141,
#   'filename': 'nuun1_0163.JPG',
#   'subjectID': 83030152},
#  {'annotation_id': 142,
#   'bbox': [1616.20654296875, 515.68017578125, 295.69482421875, 441.3994140625],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 142,
#   'filename': 'IMG_0277.JPG',
#   'subjectID': 83030806},
#  {'annotation_id': 143,
#   'bbox': [1616.20654296875, 515.68017578125, 295.69482421875, 441.3994140625],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 143,
#   'filename': 'IMG_0279.JPG',
#   'subjectID': 83030808},
#  {'annotation_id': 144,
#   'bbox': [-3.686309814453125,
#    614.2451171875,
#    252.84042358398438,
#    363.19024658203125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 144,
#   'filename': 'IMG_1448.JPG',
#   'subjectID': 83032011},
#  {'annotation_id': 145,
#   'bbox': [1811.1937255859375,
#    419.25799560546875,
#    109.2784423828125,
#    226.05645751953125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 145,
#   'filename': 'IMG_1168.JPG',
#   'subjectID': 83031731},
#  {'annotation_id': 146,
#   'bbox': [26.31170654296875,
#    618.530517578125,
#    252.84042358398438,
#    193.915771484375],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 146,
#   'filename': 'nuun1_0537.JPG',
#   'subjectID': 83030546},
#  {'annotation_id': 147,
#   'bbox': [1738.34130859375,
#    407.4730529785156,
#    173.56005859375,
#    206.77206420898438],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 147,
#   'filename': 'IMG_1293.JPG',
#   'subjectID': 83031856},
#  {'annotation_id': 148,
#   'bbox': [416.2859191894531,
#    417.1152648925781,
#    381.4033508300781,
#    281.7670593261719],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 148,
#   'filename': 'IMG_0991.JPG',
#   'subjectID': 83031526},
#  {'annotation_id': 149,
#   'bbox': [103.449462890625,
#    489.9676208496094,
#    437.11395263671875,
#    320.3359680175781],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 149,
#   'filename': 'IMG_0514.JPG',
#   'subjectID': 83031043},
#  {'annotation_id': 150,
#   'bbox': [846.9717407226562,
#    395.6881103515625,
#    171.417236328125,
#    277.48162841796875],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 150,
#   'filename': 'IMG_0658.JPG',
#   'subjectID': 83031187},
#  {'annotation_id': 151,
#   'bbox': [514.850830078125,
#    464.2550048828125,
#    64.281494140625,
#    70.7095947265625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 151,
#   'filename': 'IMG_0791.JPG',
#   'subjectID': 83031320},
#  {'annotation_id': 152,
#   'bbox': [514.850830078125,
#    464.2550048828125,
#    64.281494140625,
#    70.7095947265625],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 152,
#   'filename': 'nuun1_0081.JPG',
#   'subjectID': 83030061},
#  {'annotation_id': 153,
#   'bbox': [514.850830078125,
#    464.2550048828125,
#    64.281494140625,
#    70.7095947265625],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 153,
#   'filename': 'nuun1_0441.JPG',
#   'subjectID': 83030450},
#  {'annotation_id': 154,
#   'bbox': [1487.6436767578125,
#    292.8377685546875,
#    379.2606201171875,
#    404.97320556640625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 154,
#   'filename': 'IMG_0936.JPG',
#   'subjectID': 83031471},
#  {'annotation_id': 155,
#   'bbox': [1654.775390625,
#    391.4026794433594,
#    192.844482421875,
#    260.3399353027344],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 155,
#   'filename': 'IMG_0069.JPG',
#   'subjectID': 83030598},
#  {'annotation_id': 156,
#   'bbox': [936.9657592773438,
#    509.2520446777344,
#    177.84539794921875,
#    175.70266723632812],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 156,
#   'filename': 'IMG_1147.JPG',
#   'subjectID': 83031710},
#  {'annotation_id': 157,
#   'bbox': [546.9915771484375,
#    364.6187744140625,
#    477.8255615234375,
#    416.7581787109375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 157,
#   'filename': 'IMG_0632.JPG',
#   'subjectID': 83031161},
#  {'annotation_id': 158,
#   'bbox': [546.9915771484375,
#    364.6187744140625,
#    477.8255615234375,
#    416.7581787109375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 158,
#   'filename': 'IMG_1565.JPG',
#   'subjectID': 83030557},
#  {'annotation_id': 159,
#   'bbox': [-12.257171630859375,
#    498.5384521484375,
#    57.85331726074219,
#    121.06341552734375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 159,
#   'filename': 'IMG_0988.JPG',
#   'subjectID': 83031523},
#  {'annotation_id': 160,
#   'bbox': [1811.1937255859375,
#    417.1152648925781,
#    111.421142578125,
#    249.62637329101562],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 160,
#   'filename': 'IMG_1307.JPG',
#   'subjectID': 83031870},
#  {'annotation_id': 161,
#   'bbox': [1691.20166015625,
#    335.69207763671875,
#    227.1278076171875,
#    319.26458740234375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 161,
#   'filename': 'IMG_0934.JPG',
#   'subjectID': 83031469},
#  {'annotation_id': 162,
#   'bbox': [1626.920166015625,
#    425.6861267089844,
#    291.4093017578125,
#    265.6967468261719],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 162,
#   'filename': 'IMG_1264.JPG',
#   'subjectID': 83031827},
#  {'annotation_id': 163,
#   'bbox': [1626.920166015625,
#    425.6861267089844,
#    291.4093017578125,
#    265.6967468261719],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 163,
#   'filename': 'IMG_0519.JPG',
#   'subjectID': 83031048},
#  {'annotation_id': 164,
#   'bbox': [1626.920166015625,
#    425.6861267089844,
#    291.4093017578125,
#    265.6967468261719],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 164,
#   'filename': 'IMG_1436.JPG',
#   'subjectID': 83031999},
#  {'annotation_id': 165,
#   'bbox': [1661.20361328125,
#    465.3263854980469,
#    177.8453369140625,
#    294.6233825683594],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 165,
#   'filename': 'IMG_0119.JPG',
#   'subjectID': 83030648},
#  {'annotation_id': 166,
#   'bbox': [1661.20361328125,
#    465.3263854980469,
#    177.8453369140625,
#    294.6233825683594],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 166,
#   'filename': 'IMG_1326.JPG',
#   'subjectID': 83031889},
#  {'annotation_id': 167,
#   'bbox': [1661.20361328125,
#    465.3263854980469,
#    177.8453369140625,
#    294.6233825683594],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 167,
#   'filename': 'IMG_1302.JPG',
#   'subjectID': 83031865},
#  {'annotation_id': 168,
#   'bbox': [-3.686309814453125,
#    564.962646484375,
#    72.85232543945312,
#    100.7076416015625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 168,
#   'filename': 'nuun1_0094.JPG',
#   'subjectID': 83030074},
#  {'annotation_id': 169,
#   'bbox': [289.86572265625,
#    464.2550048828125,
#    289.2666015625,
#    334.26361083984375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 169,
#   'filename': 'nuun1_0466.JPG',
#   'subjectID': 83030475},
#  {'annotation_id': 170,
#   'bbox': [1451.217529296875,
#    474.9685974121094,
#    209.986083984375,
#    160.70364379882812],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 170,
#   'filename': 'IMG_0455.JPG',
#   'subjectID': 83030984},
#  {'annotation_id': 171,
#   'bbox': [1841.191650390625,
#    408.5444030761719,
#    77.1378173828125,
#    223.91378784179688],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 171,
#   'filename': 'IMG_0567.JPG',
#   'subjectID': 83031096},
#  {'annotation_id': 172,
#   'bbox': [-7.97174072265625,
#    492.1103210449219,
#    51.4251708984375,
#    116.77798461914062],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 172,
#   'filename': 'IMG_0985.JPG',
#   'subjectID': 83031520},
#  {'annotation_id': 173,
#   'bbox': [-7.97174072265625,
#    492.1103210449219,
#    51.4251708984375,
#    116.77798461914062],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 173,
#   'filename': 'nuun1_0551.JPG',
#   'subjectID': 83030017},
#  {'annotation_id': 174,
#   'bbox': [2.7418365478515625,
#    335.69207763671875,
#    342.83445739746094,
#    430.685791015625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 174,
#   'filename': 'IMG_0400.JPG',
#   'subjectID': 83030929},
#  {'annotation_id': 175,
#   'bbox': [1819.7645263671875,
#    417.1152648925781,
#    100.7076416015625,
#    262.4826354980469],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 175,
#   'filename': 'IMG_0809.JPG',
#   'subjectID': 83031338},
#  {'annotation_id': 176,
#   'bbox': [1689.058837890625,
#    376.4036865234375,
#    182.130859375,
#    272.1248779296875],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 176,
#   'filename': 'IMG_1214.JPG',
#   'subjectID': 83031777},
#  {'annotation_id': 177,
#   'bbox': [658.4127197265625,
#    444.9705810546875,
#    244.26959228515625,
#    302.12286376953125],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 177,
#   'filename': 'IMG_0462.JPG',
#   'subjectID': 83030991},
#  {'annotation_id': 178,
#   'bbox': [412.00048828125,
#    468.5404357910156,
#    47.139739990234375,
#    70.70962524414062],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 178,
#   'filename': 'IMG_0339.JPG',
#   'subjectID': 83030868},
#  {'annotation_id': 179,
#   'bbox': [1104.0975341796875,
#    496.395751953125,
#    72.8524169921875,
#    66.4241943359375],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 179,
#   'filename': 'nuun1_0253.JPG',
#   'subjectID': 83030252},
#  {'annotation_id': 180,
#   'bbox': [1104.0975341796875,
#    496.395751953125,
#    72.8524169921875,
#    66.4241943359375],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 180,
#   'filename': 'IMG_0765.JPG',
#   'subjectID': 83031294},
#  {'annotation_id': 181,
#   'bbox': [1575.4949951171875,
#    438.54241943359375,
#    242.1268310546875,
#    263.55401611328125],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 181,
#   'filename': 'IMG_0865.JPG',
#   'subjectID': 83031394},
#  {'annotation_id': 182,
#   'bbox': [341.2908935546875,
#    485.6821594238281,
#    145.70465087890625,
#    87.85134887695312],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 182,
#   'filename': 'IMG_0730.JPG',
#   'subjectID': 83031259},
#  {'annotation_id': 183,
#   'bbox': [737.6932373046875,
#    541.3927612304688,
#    347.119873046875,
#    323.550048828125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 183,
#   'filename': 'IMG_1110.JPG',
#   'subjectID': 83031673},
#  {'annotation_id': 184,
#   'bbox': [1241.2313232421875,
#    575.6762084960938,
#    188.5589599609375,
#    141.41925048828125],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 184,
#   'filename': 'nuun1_0046.JPG',
#   'subjectID': 83030021},
#  {'annotation_id': 185,
#   'bbox': [1241.2313232421875,
#    575.6762084960938,
#    188.5589599609375,
#    141.41925048828125],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 185,
#   'filename': 'IMG_1208.JPG',
#   'subjectID': 83031771},
#  {'annotation_id': 186,
#   'bbox': [1241.2313232421875,
#    575.6762084960938,
#    188.5589599609375,
#    141.41925048828125],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 186,
#   'filename': 'nuun1_0048.JPG',
#   'subjectID': 83030023},
#  {'annotation_id': 187,
#   'bbox': [1804.7655029296875,
#    425.6861267089844,
#    115.7066650390625,
#    220.69967651367188],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 187,
#   'filename': 'IMG_0451.JPG',
#   'subjectID': 83030980},
#  {'annotation_id': 188,
#   'bbox': [806.2601318359375,
#    468.5404357910156,
#    92.13677978515625,
#    145.70468139648438],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 188,
#   'filename': 'IMG_0372.JPG',
#   'subjectID': 83030901},
#  {'annotation_id': 189,
#   'bbox': [-16.5426025390625,
#    464.2550048828125,
#    72.85232543945312,
#    121.06341552734375],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 189,
#   'filename': 'IMG_0538.JPG',
#   'subjectID': 83031067},
#  {'annotation_id': 190,
#   'bbox': [304.8647155761719,
#    560.6771850585938,
#    310.6937561035156,
#    229.27056884765625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 190,
#   'filename': 'nuun1_0107.JPG',
#   'subjectID': 83030089},
#  {'annotation_id': 191,
#   'bbox': [-5.8290252685546875,
#    579.961669921875,
#    312.83644104003906,
#    343.90576171875],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 191,
#   'filename': 'IMG_1506.JPG',
#   'subjectID': 83032069},
#  {'annotation_id': 192,
#   'bbox': [-5.8290252685546875,
#    579.961669921875,
#    312.83644104003906,
#    343.90576171875],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 192,
#   'filename': 'IMG_0756.JPG',
#   'subjectID': 83031285},
#  {'annotation_id': 193,
#   'bbox': [-5.8290252685546875,
#    579.961669921875,
#    312.83644104003906,
#    343.90576171875],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 193,
#   'filename': 'IMG_1296.JPG',
#   'subjectID': 83031859},
#  {'annotation_id': 194,
#   'bbox': [1586.20849609375,
#    395.6881103515625,
#    261.411376953125,
#    263.55401611328125],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 194,
#   'filename': 'nuun1_0499.JPG',
#   'subjectID': 83030508},
#  {'annotation_id': 195,
#   'bbox': [1609.7784423828125,
#    434.2569885253906,
#    179.988037109375,
#    222.84243774414062],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 195,
#   'filename': 'IMG_0085.JPG',
#   'subjectID': 83030614},
#  {'annotation_id': 196,
#   'bbox': [934.8230590820312,
#    479.25396728515625,
#    160.70355224609375,
#    145.7047119140625],
#   'category_id': 7,
#   'class': 'PRONGHORN',
#   'image_id': 196,
#   'filename': 'IMG_0740.JPG',
#   'subjectID': 83031269},
#  {'annotation_id': 197,
#   'bbox': [1899.0450439453125,
#    391.4026794433594,
#    32.1407470703125,
#    269.9821472167969],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 197,
#   'filename': 'IMG_0049.JPG',
#   'subjectID': 83030578},
#  {'annotation_id': 198,
#   'bbox': [1416.93408203125,
#    449.2559814453125,
#    192.8443603515625,
#    156.418212890625],
#   'category_id': 7,
#   'class': 'AFRICANORYX',
#   'image_id': 198,
#   'filename': 'nuun1_0391.JPG',
#   'subjectID': 83030400},
#  {'annotation_id': 199,
#   'bbox': [161.3027801513672,
#    414.9725646972656,
#    124.27748107910156,
#    200.34390258789062],
#   'category_id': 7,
#   'class': 'MULEDEER',
#   'image_id': 199,
#   'filename': 'IMG_0872.JPG',
#   'subjectID': 83031401},
#  {'annotation_id': 200,
#   'bbox': [161.3027801513672,
#    414.9725646972656,
#    124.27748107910156,
#    200.34390258789062],
#   'category_id': 7,
#   'class': 'NOTHINGHERE',
#   'image_id': 200,
#   'filename': 'IMG_1433.JPG',
#   'subjectID': 83031996},
#  {'annotation_id': 201,
#   'bbox': [161.3027801513672,
# ...
#   'image_id': 934,
#   'filename': 'IMG_1535.JPG',
#   'subjectID': 83032098},
#  {'annotation_id': 935,
#   'bbox': [1811.1937255859375,
#    432.1142883300781,
#    119.9920654296875,
#    244.26956176757812],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 935,
#   'filename': 'IMG_0943.JPG',
#   'subjectID': 83031478},
#  {'annotation_id': 936,
#   'bbox': [1451.217529296875,
#    334.6207275390625,
#    351.4052734375,
#    326.76409912109375],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 936,
#   'filename': 'IMG_0989.JPG',
#   'subjectID': 83031524},
#  {'annotation_id': 937,
#   'bbox': [-3.686309814453125,
#    534.964599609375,
#    563.5341491699219,
#    440.328125],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 937,
#   'filename': 'IMG_1339.JPG',
#   'subjectID': 83031902},
#  {'annotation_id': 938,
#   'bbox': [-1.5435943603515625,
#    410.6871337890625,
#    456.3983917236328,
#    349.26263427734375],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 938,
#   'filename': 'nuun1_0411.JPG',
#   'subjectID': 83030420},
#  {'annotation_id': 939,
#   'bbox': [43.45343017578125,
#    464.2550354003906,
#    154.2755126953125,
#    126.42019653320312],
#   'category_id': 8,
#   'class': 'PRONGHORN',
#   'image_id': 939,
#   'filename': 'IMG_0343.JPG',
#   'subjectID': 83030872},
#  {'annotation_id': 940,
#   'bbox': [22.026275634765625,
#    457.8268737792969,
#    252.84042358398438,
#    175.70266723632812],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 940,
#   'filename': 'IMG_0613.JPG',
#   'subjectID': 83031142},
#  {'annotation_id': 941,
#   'bbox': [1530.4979248046875,
#    356.0478820800781,
#    229.2706298828125,
#    256.0545349121094],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 941,
#   'filename': 'IMG_1444.JPG',
#   'subjectID': 83032007},
#  {'annotation_id': 942,
#   'bbox': [1479.07275390625,
#    391.4027099609375,
#    117.849365234375,
#    141.419189453125],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 942,
#   'filename': 'IMG_1266.JPG',
#   'subjectID': 83031829},
#  {'annotation_id': 943,
#   'bbox': [1479.07275390625,
#    391.4027099609375,
#    117.849365234375,
#    141.419189453125],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 943,
#   'filename': 'nuun1_0329.JPG',
#   'subjectID': 83030336},
#  {'annotation_id': 944,
#   'bbox': [1693.3443603515625,
#    483.53948974609375,
#    227.1278076171875,
#    446.75616455078125],
#   'category_id': 8,
#   'class': 'PRONGHORN',
#   'image_id': 944,
#   'filename': 'IMG_1478.JPG',
#   'subjectID': 83032041},
#  {'annotation_id': 945,
#   'bbox': [1693.3443603515625,
#    483.53948974609375,
#    227.1278076171875,
#    446.75616455078125],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 945,
#   'filename': 'IMG_0803.JPG',
#   'subjectID': 83031332},
#  {'annotation_id': 946,
#   'bbox': [0.59912109375,
#    467.4690856933594,
#    857.086181640625,
#    586.0326232910156],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 946,
#   'filename': 'IMG_0815.JPG',
#   'subjectID': 83031344},
#  {'annotation_id': 947,
#   'bbox': [1727.6278076171875,
#    449.25604248046875,
#    190.70166015625,
#    357.83343505859375],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 947,
#   'filename': 'IMG_0370.JPG',
#   'subjectID': 83030899},
#  {'annotation_id': 948,
#   'bbox': [1727.6278076171875,
#    449.25604248046875,
#    190.70166015625,
#    357.83343505859375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 948,
#   'filename': 'IMG_0467.JPG',
#   'subjectID': 83030996},
#  {'annotation_id': 949,
#   'bbox': [1389.0787353515625,
#    350.69110107421875,
#    299.9801025390625,
#    286.052490234375],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 949,
#   'filename': 'IMG_1278.JPG',
#   'subjectID': 83031841},
#  {'annotation_id': 950,
#   'bbox': [1524.06982421875,
#    342.1202392578125,
#    282.8385009765625,
#    299.980224609375],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 950,
#   'filename': 'IMG_0926.JPG',
#   'subjectID': 83031461},
#  {'annotation_id': 951,
#   'bbox': [1391.221435546875,
#    494.2530517578125,
#    162.846435546875,
#    249.6263427734375],
#   'category_id': 8,
#   'class': 'PRONGHORN',
#   'image_id': 951,
#   'filename': 'nuun1_0078.JPG',
#   'subjectID': 83030058},
#  {'annotation_id': 952,
#   'bbox': [47.738861083984375,
#    477.1112976074219,
#    207.84339904785156,
#    175.70266723632812],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 952,
#   'filename': 'IMG_0252.JPG',
#   'subjectID': 83030781},
#  {'annotation_id': 953,
#   'bbox': [47.738861083984375,
#    477.1112976074219,
#    207.84339904785156,
#    175.70266723632812],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 953,
#   'filename': 'nuun1_0399.JPG',
#   'subjectID': 83030408},
#  {'annotation_id': 954,
#   'bbox': [47.738861083984375,
#    477.1112976074219,
#    207.84339904785156,
#    175.70266723632812],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 954,
#   'filename': 'IMG_0166.JPG',
#   'subjectID': 83030695},
#  {'annotation_id': 955,
#   'bbox': [0.59912109375, 462.1123046875, 160.7036590576172, 269.982177734375],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 955,
#   'filename': 'nuun1_0481.JPG',
#   'subjectID': 83030490},
#  {'annotation_id': 956,
#   'bbox': [1721.1995849609375,
#    425.6861572265625,
#    201.415283203125,
#    254.983154296875],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 956,
#   'filename': 'IMG_0223.JPG',
#   'subjectID': 83030752},
#  {'annotation_id': 957,
#   'bbox': [1721.1995849609375,
#    425.6861572265625,
#    201.415283203125,
#    254.983154296875],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 957,
#   'filename': 'IMG_1043.JPG',
#   'subjectID': 83031588},
#  {'annotation_id': 958,
#   'bbox': [1721.1995849609375,
#    425.6861572265625,
#    201.415283203125,
#    254.983154296875],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 958,
#   'filename': 'IMG_0846.JPG',
#   'subjectID': 83031375},
#  {'annotation_id': 959,
#   'bbox': [-5.8290252685546875,
#    457.8268737792969,
#    394.25965881347656,
#    519.6084899902344],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 959,
#   'filename': 'IMG_1136.JPG',
#   'subjectID': 83031699},
#  {'annotation_id': 960,
#   'bbox': [-5.8290252685546875,
#    457.8268737792969,
#    394.25965881347656,
#    519.6084899902344],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 960,
#   'filename': 'IMG_0063.JPG',
#   'subjectID': 83030592},
#  {'annotation_id': 961,
#   'bbox': [1699.7724609375,
#    446.04193115234375,
#    224.985107421875,
#    271.05352783203125],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 961,
#   'filename': 'IMG_0685.JPG',
#   'subjectID': 83031214},
#  {'annotation_id': 962,
#   'bbox': [1258.373046875,
#    362.47601318359375,
#    263.5540771484375,
#    309.62237548828125],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 962,
#   'filename': 'IMG_0582.JPG',
#   'subjectID': 83031111},
#  {'annotation_id': 963,
#   'bbox': [1258.373046875,
#    362.47601318359375,
#    263.5540771484375,
#    309.62237548828125],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 963,
#   'filename': 'IMG_0533.JPG',
#   'subjectID': 83031062},
#  {'annotation_id': 964,
#   'bbox': [0.59912109375,
#    434.25701904296875,
#    188.5589599609375,
#    235.69866943359375],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 964,
#   'filename': 'IMG_1084.JPG',
#   'subjectID': 83031644},
#  {'annotation_id': 965,
#   'bbox': [311.2928466796875,
#    399.97357177734375,
#    342.83447265625,
#    308.551025390625],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 965,
#   'filename': 'IMG_0266.JPG',
#   'subjectID': 83030795},
#  {'annotation_id': 966,
#   'bbox': [311.2928466796875,
#    399.97357177734375,
#    342.83447265625,
#    308.551025390625],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 966,
#   'filename': 'IMG_0278.JPG',
#   'subjectID': 83030807},
#  {'annotation_id': 967,
#   'bbox': [313.4355773925781,
#    386.0458984375,
#    342.8344421386719,
#    318.1932373046875],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 967,
#   'filename': 'IMG_0262.JPG',
#   'subjectID': 83030791},
#  {'annotation_id': 968,
#   'bbox': [1689.058837890625,
#    327.1212158203125,
#    229.2706298828125,
#    379.2606201171875],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 968,
#   'filename': 'IMG_0670.JPG',
#   'subjectID': 83031199},
#  {'annotation_id': 969,
#   'bbox': [491.28094482421875,
#    485.68218994140625,
#    250.69769287109375,
#    173.5599365234375],
#   'category_id': 8,
#   'class': 'PRONGHORN',
#   'image_id': 969,
#   'filename': 'IMG_0794.JPG',
#   'subjectID': 83031323},
#  {'annotation_id': 970,
#   'bbox': [491.28094482421875,
#    485.68218994140625,
#    250.69769287109375,
#    173.5599365234375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 970,
#   'filename': 'IMG_0980.JPG',
#   'subjectID': 83031515},
#  {'annotation_id': 971,
#   'bbox': [347.7190246582031,
#    479.2540283203125,
#    439.2566833496094,
#    569.9622802734375],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 971,
#   'filename': 'IMG_0508.JPG',
#   'subjectID': 83031037},
#  {'annotation_id': 972,
#   'bbox': [-10.114456176757812,
#    515.68017578125,
#    235.69869995117188,
#    185.34490966796875],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 972,
#   'filename': 'nuun1_0215.JPG',
#   'subjectID': 83030209},
#  {'annotation_id': 973,
#   'bbox': [-10.114456176757812,
#    515.68017578125,
#    235.69869995117188,
#    185.34490966796875],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 973,
#   'filename': 'nuun1_0090.JPG',
#   'subjectID': 83030070},
#  {'annotation_id': 974,
#   'bbox': [1485.5009765625,
#    444.9705810546875,
#    242.1268310546875,
#    212.12884521484375],
#   'category_id': 8,
#   'class': 'PRONGHORN',
#   'image_id': 974,
#   'filename': 'IMG_0496.JPG',
#   'subjectID': 83031025},
#  {'annotation_id': 975,
#   'bbox': [-16.5426025390625,
#    573.5335083007812,
#    92.13676452636719,
#    85.7086181640625],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 975,
#   'filename': 'IMG_0365.JPG',
#   'subjectID': 83030894},
#  {'annotation_id': 976,
#   'bbox': [748.4067993164062,
#    487.82489013671875,
#    179.98809814453125,
#    137.1337890625],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 976,
#   'filename': 'IMG_0140.JPG',
#   'subjectID': 83030669},
#  {'annotation_id': 977,
#   'bbox': [1894.759521484375,
#    432.11431884765625,
#    38.5689697265625,
#    64.28143310546875],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 977,
#   'filename': 'IMG_1400.JPG',
#   'subjectID': 83031963},
#  {'annotation_id': 978,
#   'bbox': [1888.3314208984375,
#    437.4710693359375,
#    42.8543701171875,
#    253.91180419921875],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 978,
#   'filename': 'IMG_0584.JPG',
#   'subjectID': 83031113},
#  {'annotation_id': 979,
#   'bbox': [564.13330078125,
#    444.9705810546875,
#    79.28045654296875,
#    113.56396484375],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 979,
#   'filename': 'IMG_0100.JPG',
#   'subjectID': 83030629},
#  {'annotation_id': 980,
#   'bbox': [564.13330078125,
#    444.9705810546875,
#    79.28045654296875,
#    113.56396484375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 980,
#   'filename': 'IMG_1006.JPG',
#   'subjectID': 83031541},
#  {'annotation_id': 981,
#   'bbox': [564.13330078125,
#    444.9705810546875,
#    79.28045654296875,
#    113.56396484375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 981,
#   'filename': 'IMG_0348.JPG',
#   'subjectID': 83030877},
#  {'annotation_id': 982,
#   'bbox': [1528.355224609375,
#    466.39776611328125,
#    214.2716064453125,
#    167.13177490234375],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 982,
#   'filename': 'IMG_0366.JPG',
#   'subjectID': 83030895},
#  {'annotation_id': 983,
#   'bbox': [1528.355224609375,
#    466.39776611328125,
#    214.2716064453125,
#    167.13177490234375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 983,
#   'filename': 'nuun1_0131.JPG',
#   'subjectID': 83030115},
#  {'annotation_id': 984,
#   'bbox': [1489.786376953125,
#    312.1222229003906,
#    239.984130859375,
#    434.9712219238281],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 984,
#   'filename': 'IMG_0593.JPG',
#   'subjectID': 83031122},
#  {'annotation_id': 985,
#   'bbox': [1826.192626953125,
#    469.61181640625,
#    92.1368408203125,
#    161.7750244140625],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 985,
#   'filename': 'IMG_1112.JPG',
#   'subjectID': 83031675},
#  {'annotation_id': 986,
#   'bbox': [1429.790283203125,
#    377.47503662109375,
#    379.2607421875,
#    320.33599853515625],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 986,
#   'filename': 'IMG_0188.JPG',
#   'subjectID': 83030717},
#  {'annotation_id': 987,
#   'bbox': [-7.97174072265625,
#    459.9696044921875,
#    98.56491088867188,
#    152.1328125],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 987,
#   'filename': 'IMG_1516.JPG',
#   'subjectID': 83032079},
#  {'annotation_id': 988,
#   'bbox': [-7.97174072265625,
#    459.9696044921875,
#    98.56491088867188,
#    152.1328125],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 988,
#   'filename': 'IMG_1048.JPG',
#   'subjectID': 83031594},
#  {'annotation_id': 989,
#   'bbox': [292.0084228515625,
#    534.9646606445312,
#    497.1099853515625,
#    387.83148193359375],
#   'category_id': 8,
#   'class': 'PRONGHORN',
#   'image_id': 989,
#   'filename': 'IMG_0080.JPG',
#   'subjectID': 83030609},
#  {'annotation_id': 990,
#   'bbox': [292.0084228515625,
#    534.9646606445312,
#    497.1099853515625,
#    387.83148193359375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 990,
#   'filename': 'IMG_1509.JPG',
#   'subjectID': 83032072},
#  {'annotation_id': 991,
#   'bbox': [292.0084228515625,
#    534.9646606445312,
#    497.1099853515625,
#    387.83148193359375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 991,
#   'filename': 'IMG_0707.JPG',
#   'subjectID': 83031236},
#  {'annotation_id': 992,
#   'bbox': [292.0084228515625,
#    534.9646606445312,
#    497.1099853515625,
#    387.83148193359375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 992,
#   'filename': 'IMG_0708.JPG',
#   'subjectID': 83031237},
#  {'annotation_id': 993,
#   'bbox': [292.0084228515625,
#    534.9646606445312,
#    497.1099853515625,
#    387.83148193359375],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 993,
#   'filename': 'IMG_0690.JPG',
#   'subjectID': 83031219},
#  {'annotation_id': 994,
#   'bbox': [1352.652587890625,
#    464.2550354003906,
#    229.2705078125,
#    273.1961975097656],
#   'category_id': 8,
#   'class': 'PRONGHORN',
#   'image_id': 994,
#   'filename': 'IMG_0851.JPG',
#   'subjectID': 83031380},
#  {'annotation_id': 995,
#   'bbox': [1352.652587890625,
#    464.2550354003906,
#    229.2705078125,
#    273.1961975097656],
#   'category_id': 8,
#   'class': 'NOTHINGHERE',
#   'image_id': 995,
#   'filename': 'nuun1_0350.JPG',
#   'subjectID': 83030357},
#  {'annotation_id': 996,
#   'bbox': [1785.4810791015625,
#    455.68414306640625,
#    141.419189453125,
#    113.56390380859375],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 996,
#   'filename': 'IMG_0034.JPG',
#   'subjectID': 83030563},
#  {'annotation_id': 997,
#   'bbox': [1423.3621826171875,
#    421.4007263183594,
#    338.549072265625,
#    217.48562622070312],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 997,
#   'filename': 'IMG_0876.JPG',
#   'subjectID': 83031405},
#  {'annotation_id': 998,
#   'bbox': [1446.9320068359375,
#    506.0379638671875,
#    357.83349609375,
#    305.33697509765625],
#   'category_id': 8,
#   'class': 'MULEDEER',
#   'image_id': 998,
#   'filename': 'nuun1_0337.JPG',
#   'subjectID': 83030344},
#  {'annotation_id': 999,
#   'bbox': [1498.357177734375,
#    463.18365478515625,
#    244.2696533203125,
#    183.20220947265625],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 999,
#   'filename': 'nuun1_0502.JPG',
#   'subjectID': 83030511},
#  {'annotation_id': 1000,
#   'bbox': [116.30575561523438,
#    376.4036865234375,
#    497.1100158691406,
#    453.184326171875],
#   'category_id': 8,
#   'class': 'AFRICANORYX',
#   'image_id': 1000,
#   'filename': 'nuun1_0464.JPG',
#   'subjectID': 83030473},
#  ...]

# %%
len(annos)
# Out:
# 2073

# %%
for i in range(len(zooniverse)):
   row = json.loads(zooniverse["annotations"][i])
   if row[j]['task'] == 'T0': 
      labelinfo = row[j]['value']
      for k in range(len(labelinfo)):
            lbl = labelinfo[k]
            label = lbl["choice"]
            if label not in categories:
   #label class has not yet been registered; add
                  categories[label] = len(categories) + 1
                  category_id = categories[label]
      annotation = {
        'annotation_id': len(annos)+1,
        'category_id': category_id,
        'class': label,
      }
      annos.append(annotation)
annos
# Out:
# [{'annotation_id': 1, 'category_id': 1, 'class': 'MULEDEER'},
#  {'annotation_id': 2, 'category_id': 2, 'class': 'PRONGHORN'},
#  {'annotation_id': 3, 'category_id': 4, 'class': 'VEHICLE'},
#  {'annotation_id': 4, 'category_id': 4, 'class': 'HUMAN'},
#  {'annotation_id': 5, 'category_id': 4, 'class': 'HUMAN'},
#  {'annotation_id': 6, 'category_id': 4, 'class': 'VEHICLE'},
#  {'annotation_id': 7, 'category_id': 5, 'class': 'AFRICANORYX'},
#  {'annotation_id': 8, 'category_id': 5, 'class': 'AFRICANORYX'},
#  {'annotation_id': 9, 'category_id': 5, 'class': 'MULEDEER'},
#  {'annotation_id': 10, 'category_id': 5, 'class': 'PRONGHORN'},
#  {'annotation_id': 11, 'category_id': 5, 'class': 'PRONGHORN'},
#  {'annotation_id': 12, 'category_id': 5, 'class': 'MULEDEER'},
#  {'annotation_id': 13, 'category_id': 5, 'class': 'AFRICANORYX'},
#  {'annotation_id': 14, 'category_id': 6, 'class': 'ELK'},
#  {'annotation_id': 15, 'category_id': 6, 'class': 'VEHICLE'},
#  {'annotation_id': 16, 'category_id': 7, 'class': 'JAVELINA'},
#  {'annotation_id': 17, 'category_id': 7, 'class': 'VEHICLE'},
#  {'annotation_id': 18, 'category_id': 7, 'class': 'VEHICLE'},
#  {'annotation_id': 19, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 20, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 21, 'category_id': 7, 'class': 'PRONGHORN'},
#  {'annotation_id': 22, 'category_id': 7, 'class': 'AFRICANORYX'},
#  {'annotation_id': 23, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 24, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 25, 'category_id': 7, 'class': 'HUMAN'},
#  {'annotation_id': 26, 'category_id': 7, 'class': 'VEHICLE'},
#  {'annotation_id': 27, 'category_id': 7, 'class': 'MULEDEER'},
#  {'annotation_id': 28, 'category_id': 8, 'class': 'COUGAR'},
#  {'annotation_id': 29, 'category_id': 8, 'class': 'HUMAN'},
#  {'annotation_id': 30, 'category_id': 8, 'class': 'HUMAN'}]

# %%
#load camera ID
camID = pd.read_csv(r'/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Labels/rowanID_camerainfo')
camID.head()
# Out:
#    Unnamed: 0  image_id        filename  camera
# 0           0  83030012  nuun1_0546.JPG  109891
# 1           1  83030013  nuun1_0547.JPG  109891
# 2           2  83030014  nuun1_0548.JPG  109891
# 3           3  83030015  nuun1_0549.JPG  109891
# 4           4  83030016  nuun1_0550.JPG  109891

# %%
sev = pd.DataFrame(annos)
sev.head()
# Out:
#    annotation_id                                               bbox  \
# 0              1  [735.9075317382812, 462.56317138671875, 101.02...
# 1              2  [1568.1363525390625, 467.3737487792969, 336.73...
# 2              3  [1517.202392578125, 336.9212951660156, 224.376...
# 3              4  [1517.202392578125, 336.9212951660156, 224.376...
# 4              5  [1615.500732421875, 475.8211669921875, 181.638...
#
#    category_id        class  image_id      filename  subjectID
# 0            1     MULEDEER         1  IMG_1203.JPG   74583293
# 1            2      VEHICLE         2  IMG_0044.JPG   74583836
# 2            3  AFRICANORYX         3  IMG_0606.JPG   74582696
# 3            3  AFRICANORYX         4  IMG_1526.JPG   74583616
# 4            3     MULEDEER         5  IMG_1334.JPG   74583424

# %%
addcams = pd.merge(sev, camID, how='left', left_on=["subjectID"], right_on=["image_id"])
addcams.head()
# Out:
#    annotation_id                                               bbox  \
# 0              1  [735.9075317382812, 462.56317138671875, 101.02...
# 1              2  [1568.1363525390625, 467.3737487792969, 336.73...
# 2              3  [1517.202392578125, 336.9212951660156, 224.376...
# 3              4  [1517.202392578125, 336.9212951660156, 224.376...
# 4              5  [1615.500732421875, 475.8211669921875, 181.638...
#
#    category_id        class  image_id_x    filename_x  subjectID  Unnamed: 0  \
# 0            1     MULEDEER           1  IMG_1203.JPG   74583293         0.0
# 1            2      VEHICLE           2  IMG_0044.JPG   74583836         1.0
# 2            3  AFRICANORYX           3  IMG_0606.JPG   74582696         2.0
# 3            3  AFRICANORYX           4  IMG_1526.JPG   74583616         3.0
# 4            3     MULEDEER           5  IMG_1334.JPG   74583424         4.0
#
#    image_id_y    filename_y    camera
# 0  74583293.0  IMG_1203.JPG  103602.0
# 1  74583836.0  IMG_0044.JPG       NaN
# 2  74582696.0  IMG_0606.JPG  103602.0
# 3  74583616.0  IMG_1526.JPG  103602.0
# 4  74583424.0  IMG_1334.JPG  103602.0

# %%
cleancams = addcams.drop(['image_id_y', 'filename_y', 'Unnamed: 0'], axis=1)
cleancams = cleancams.rename({'image_id_x': 'imageID', 'filename_x': 'filename'}, axis=1)
cleancams.head()
# Out:
#    annotation_id                                               bbox  \
# 0              1  [735.9075317382812, 462.56317138671875, 101.02...
# 1              2  [1568.1363525390625, 467.3737487792969, 336.73...
# 2              3  [1517.202392578125, 336.9212951660156, 224.376...
# 3              4  [1517.202392578125, 336.9212951660156, 224.376...
# 4              5  [1615.500732421875, 475.8211669921875, 181.638...
#
#    category_id        class  imageID      filename  subjectID    camera
# 0            1     MULEDEER        1  IMG_1203.JPG   74583293  103602.0
# 1            2      VEHICLE        2  IMG_0044.JPG   74583836       NaN
# 2            3  AFRICANORYX        3  IMG_0606.JPG   74582696  103602.0
# 3            3  AFRICANORYX        4  IMG_1526.JPG   74583616  103602.0
# 4            3     MULEDEER        5  IMG_1334.JPG   74583424  103602.0

# %%
cleancams.camera.value_counts()
# Out:
# 103602.0    24907
# 106190.0     1375
# Name: camera, dtype: int64

# %%
cleancams.to_csv("sev_ann_cam.csv", sep=',')

# %%
newpath = r"/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Labels/sevilleta_clean.csv"
clean = pd.read_csv(newpath)
clean = clean.drop('Unnamed: 8', axis=1)
clean.head()
# Out:
#    annotation_id                                               bbox  \
# 0              1  [735.9075317382812, 462.56317138671875, 101.02...
# 1              3  [1517.202392578125, 336.9212951660156, 224.376...
# 2              4  [1517.202392578125, 336.9212951660156, 224.376...
# 3              5  [1615.500732421875, 475.8211669921875, 181.638...
# 4              6  [10.168608665466309, 115.3065185546875, 816.50...
#
#    category_id        class  imageID      filename  subjectID  camera
# 0            1     MULEDEER        1  IMG_1203.JPG   74583293   Nuun2
# 1            3  AFRICANORYX        3  IMG_0606.JPG   74582696   Nuun2
# 2            3  AFRICANORYX        4  IMG_1526.JPG   74583616   Nuun2
# 3            3     MULEDEER        5  IMG_1334.JPG   74583424   Nuun2
# 4            3     MULEDEER        6  IMG_0087.JPG   78164412  106190

# %%
clean.to_csv("clean_sevilleta.csv", sep=',')

# %%
with open("sev_annos_cams.json", "w") as outfile:
    json.dump(cleancams, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb Cell 11 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> with open("sev_annos_cams.json", "w") as outfile:
# ----> <a href='vscode-notebook-cell:/Users/rowanconverse/Library/CloudStorage/OneDrive-UniversityofNewMexico/Projects/CameraTraps/Scripts/WildSouthwest/Scratch/sev_zooniverse2COCO.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     json.dump(cleancams, outfile)
#
# File ~/miniconda3/envs/dronesforducks/lib/python3.8/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~/miniconda3/envs/dronesforducks/lib/python3.8/json/encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File ~/miniconda3/envs/dronesforducks/lib/python3.8/json/encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type DataFrame is not JSON serializable
